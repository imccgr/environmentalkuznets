# %%
#import required libraries
import pandas as pd
import numpy as np

# %%
#make a dataframe from all the indicators data
indicators_df = pd.read_csv("indicators_clean.csv")
indicators_df.head()
# Out:
#   Country Code GNI per capita, Atlas method (current US$)  \
# 0          ABW                                      28330
# 1          AFG                                        510
# 2          AGO                                       1900
# 3          ALB                                       4860
# 4          AND                                         ..
#
#   Labor force, female (% of total labor force)  \
# 0                                           ..
# 1                           21.741485654167413
# 2                            49.60658575105186
# 3                           42.720264348661246
# 4                                           ..
#
#   Life expectancy at birth, total (years)  Population growth (annual %)  \
# 0                                  76.152                      0.459266
# 1                                  64.486                      2.384309
# 2                                  60.782                      3.276145
# 3                                  78.458                     -0.246732
# 4                                      ..                      0.014285
#
#    Population, total  \
# 0             105846
# 1           37171922
# 2           30809787
# 3            2866376
# 4              77008
#
#   Poverty headcount ratio at national poverty line (% of population)  \
# 0                                                 ..
# 1                                                 ..
# 2                                               32.3
# 3                                                 23
# 4                                                 ..
#
#   Public spending on education, total (% of GDP)  \
# 0                                             ..
# 1                               3.19979000091553
# 2                               2.04470133781433
# 3                                             ..
# 4                                3.2467200756073
#
#   Rural population (% of total population) School enrollment, primary (% net)  \
# 0                                   56.589                                 ..
# 1                                   74.505                                 ..
# 2                       34.486000000000004                                 ..
# 3                                   39.681                           94.52966
# 4                       11.938000000000002                                 ..
#
#   Urban population (% of total population)
# 0                                   43.411
# 1                                   25.495
# 2                                   65.514
# 3                                   60.319
# 4                                   88.062

# %%
#make a dataframe from the PM2.5 data (and clean it slightly)
pm25_df = pd.read_csv("../API code and csv file/PM25_data.csv")
pm25_df = pm25_df.drop('Unnamed: 0', axis=1)
pm25_df = pm25_df.rename(columns={'Country:': 'Country Code'}) #rename column to facilitate merging
pm25_df.head()
# Out:
#   Country Code  2010 Total:  2011 Total:  2012 Total:  2013 Total:  \
# 0          AFG     68.96605     66.94454     68.25744     72.18289
# 1          AGO     24.19840     24.67357     24.00830     24.53186
# 2          ALB     21.94870     22.99650     21.70175     19.77038
# 3          AND     11.42903     11.66004     10.79727     10.14877
# 4          ARE     43.70844     43.53498     43.93421     42.88311
#
#    2014 Total:  2015 Total:  2016 Total:  2017 Total:  2018 Total:  \
# 0     68.05715     67.20320     64.00314     61.77561     70.25405
# 1     24.11941     25.03078     26.08120     25.44195     25.85236
# 2     19.13142     18.98271     18.14981     19.00622     19.75808
# 3      9.34741      9.94171      9.06227      9.30733      9.21394
# 4     41.33546     43.92792     42.88604     43.32676     43.09622
#
#    2019 Total:
# 0     62.48616
# 1     27.16477
# 2     16.27997
# 3      8.52423
# 4     41.74950

# %%
final_data = indicators_df.merge(pm25_df, on = 'Country Code') #merge two dataframes

# %%
#rename columns for better comprehension
final_data = final_data.rename(columns={'City Average:': 'City Average PM2.5','Total Average:': 'Total Average PM2.5' })

# %%
final_data.head() #take a look
# Out:
#   Country Code GNI per capita, Atlas method (current US$)  \
# 0          AFG                                        510
# 1          AGO                                       1900
# 2          ALB                                       4860
# 3          AND                                         ..
# 4          ARE                                      41470
#
#   Labor force, female (% of total labor force)  \
# 0                           21.741485654167413
# 1                            49.60658575105186
# 2                           42.720264348661246
# 3                                           ..
# 4                           16.933394884621272
#
#   Life expectancy at birth, total (years)  Population growth (annual %)  \
# 0                                  64.486                      2.384309
# 1                                  60.782                      3.276145
# 2                                  78.458                     -0.246732
# 3                                      ..                      0.014285
# 4                                  77.814                      1.503938
#
#    Population, total  \
# 0           37171922
# 1           30809787
# 2            2866376
# 3              77008
# 4            9630966
#
#   Poverty headcount ratio at national poverty line (% of population)  \
# 0                                                 ..
# 1                                               32.3
# 2                                                 23
# 3                                                 ..
# 4                                                 ..
#
#   Public spending on education, total (% of GDP)  \
# 0                               3.19979000091553
# 1                               2.04470133781433
# 2                                             ..
# 3                                3.2467200756073
# 4                                             ..
#
#   Rural population (% of total population) School enrollment, primary (% net)  \
# 0                                   74.505                                 ..
# 1                       34.486000000000004                                 ..
# 2                                   39.681                           94.52966
# 3                       11.938000000000002                                 ..
# 4                       13.477999999999994                                 ..
#
#    ... 2010 Total:  2011 Total:  2012 Total:  2013 Total:  2014 Total:  \
# 0  ...    68.96605     66.94454     68.25744     72.18289     68.05715
# 1  ...    24.19840     24.67357     24.00830     24.53186     24.11941
# 2  ...    21.94870     22.99650     21.70175     19.77038     19.13142
# 3  ...    11.42903     11.66004     10.79727     10.14877      9.34741
# 4  ...    43.70844     43.53498     43.93421     42.88311     41.33546
#
#    2015 Total:  2016 Total:  2017 Total:  2018 Total:  2019 Total:
# 0     67.20320     64.00314     61.77561     70.25405     62.48616
# 1     25.03078     26.08120     25.44195     25.85236     27.16477
# 2     18.98271     18.14981     19.00622     19.75808     16.27997
# 3      9.94171      9.06227      9.30733      9.21394      8.52423
# 4     43.92792     42.88604     43.32676     43.09622     41.74950
#
# [5 rows x 21 columns]

# %%
final_data.to_csv('final_dataframe.csv')
