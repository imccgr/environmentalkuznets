# %%
#import required libraries
import pandas as pd
import numpy as np

# %%
#import data and take a look
indicators_df = pd.read_excel("indicators_unclean.xlsx")
indicators_df.head()
# Out:
#                                 Series Name        Series Code  \
# 0  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 1  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 2  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 3  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
# 4  Urban population (% of total population)  SP.URB.TOTL.IN.ZS
#
#      Country Name Country Code 2018 [YR2018] 2020 [YR2020]  Unnamed: 6  \
# 0     Afghanistan          AFG        25.495        26.026         NaN
# 1         Albania          ALB        60.319        62.112         NaN
# 2         Algeria          DZA        72.629        73.733         NaN
# 3  American Samoa          ASM        87.153        87.153         NaN
# 4         Andorra          AND        88.062        87.916         NaN
#
#    Unnamed: 7                  Data Source   Unnamed: 9
# 0         NaN            Last Updated Date          NaN
# 1         NaN                          NaN          NaN
# 2         NaN                 Country Name  2017.000000
# 3         NaN                        Aruba          NaN
# 4         NaN  Africa Eastern and Southern    35.512988

# %%
#delete useless columns
indicators_df.drop(['Country Name','Series Code','Unnamed: 6','Unnamed: 7', 'Data Source','Unnamed: 9','2020 [YR2020]'], inplace=True, axis=1)

# %%
indicators_df.head()
# Out:
#                                 Series Name Country Code 2018 [YR2018]
# 0  Urban population (% of total population)          AFG        25.495
# 1  Urban population (% of total population)          ALB        60.319
# 2  Urban population (% of total population)          DZA        72.629
# 3  Urban population (% of total population)          ASM        87.153
# 4  Urban population (% of total population)          AND        88.062

# %%
#make lists with the information we need
countries_name = indicators_df['Country Code'].unique()
series_name = indicators_df['Series Name'].unique()
year = indicators_df['2018 [YR2018]'].unique()

# %%
#create a new dataframe from these lists
final_df = pd.DataFrame({'Country Code': indicators_df['Country Code'],
                   'Series Name': indicators_df['Series Name'],
                   '2018 [YR2018]': indicators_df['2018 [YR2018]']})
final_df = final_df. dropna() #drop the NAN which show missing data as it creates a bug when doing pivot()
final_df.head()
# Out:
#   Country Code                               Series Name 2018 [YR2018]
# 0          AFG  Urban population (% of total population)        25.495
# 1          ALB  Urban population (% of total population)        60.319
# 2          DZA  Urban population (% of total population)        72.629
# 3          ASM  Urban population (% of total population)        87.153
# 4          AND  Urban population (% of total population)        88.062

# %%
#pivot the dataframe from long to wide
final_df = pd.pivot(final_df, index='Country Code', columns='Series Name', values='2018 [YR2018]')

# %%
final_df.head()
# Out:
# Series Name  GNI per capita, Atlas method (current US$)  \
# Country Code
# ABW                                               28330
# AFG                                                 510
# AGO                                                1900
# ALB                                                4860
# AND                                                  ..
#
# Series Name  Labor force, female (% of total labor force)  \
# Country Code
# ABW                                                    ..
# AFG                                             21.741486
# AGO                                             49.606586
# ALB                                             42.720264
# AND                                                    ..
#
# Series Name  Life expectancy at birth, total (years)  \
# Country Code
# ABW                                           76.152
# AFG                                           64.486
# AGO                                           60.782
# ALB                                           78.458
# AND                                               ..
#
# Series Name  Population growth (annual %) Population, total  \
# Country Code
# ABW                              0.459266            105846
# AFG                              2.384309          37171922
# AGO                              3.276145          30809787
# ALB                             -0.246732           2866376
# AND                              0.014285             77008
#
# Series Name  Poverty headcount ratio at national poverty line (% of population)  \
# Country Code
# ABW                                                          ..
# AFG                                                          ..
# AGO                                                        32.3
# ALB                                                          23
# AND                                                          ..
#
# Series Name  Public spending on education, total (% of GDP)  \
# Country Code
# ABW                                                      ..
# AFG                                                 3.19979
# AGO                                                2.044701
# ALB                                                      ..
# AND                                                 3.24672
#
# Series Name  Rural population (% of total population)  \
# Country Code
# ABW                                            56.589
# AFG                                            74.505
# AGO                                            34.486
# ALB                                            39.681
# AND                                            11.938
#
# Series Name  School enrollment, primary (% net)  \
# Country Code
# ABW                                          ..
# AFG                                          ..
# AGO                                          ..
# ALB                                    94.52966
# AND                                          ..
#
# Series Name  Urban population (% of total population)
# Country Code
# ABW                                            43.411
# AFG                                            25.495
# AGO                                            65.514
# ALB                                            60.319
# AND                                            88.062

# %%
final_df.to_csv('indicators_clean.csv')
